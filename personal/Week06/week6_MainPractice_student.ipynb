# %% [markdown]
# # 1️⃣ Data Handling
# ## Import libraries & Load Data

# %% [markdown]
# HW_5 by 21901023 박건우
#
# 1.Objective : This code reads data from data_set_train.xlsx and practice time series.
#
# 2.Input
#
# data_set_train.xlsx
#
# 3.Output
#
# printout the results(plots)

# %%
#data handling
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
df = pd.read_excel('data_set_train.xlsx')

# %% [markdown]
# ## See How Data Look Like

# %%
df.shape
# Out:
# (17400, 29)

# %%
df.columns
# Out:
# Index(['aptnm(아파트 이름)', 'yyyyqrt(거래년도 분기별)', 'price(가격)', 'con_year(건축년도)',
#        'dong(동)', 'area(면적)', 'floor(층수)', 'Latitude(위도)', 'Longtitude(경도)',
#        'gdp', 'e_grwth(경제성장률)', 'Seoul_l.rate(지가상승률)', 'house_rate(담보대출금리)',
#        'dis_park(국립 공원과의 거리)', 'dis_highschool(고등학교와의 거리)',
#        'dis_reconst(재개발 지역과의 거리)', 'dis_univ(대학과의 거리)',
#        'dis_hospital(종합 병원과의 거리)', 'dis_museum(국립 박물관과의 거리)',
#        'dis_subway(지하철역과의 거리)', 'brand_r(유명 아파트 브랜드순)', 'n_home(세대수)',
#        'n_dong(동수)', 'parking_per(세대별 주차장수)', 'Heater(난방 시스템)', 'Yongpae(용적률)',
#        'Gunpae(건폐율)', 'Highest(최고층)', 'Lowest(최저층)'],
#       dtype='object')

# %%
df.describe()
# Out:
#            price(가격)  con_year(건축년도)      area(면적)     floor(층수)  \
# count   17400.000000    17400.000000  17400.000000  17400.000000
# mean    80334.523736     1992.928563     71.217003      7.451322
# std     45557.247993       10.250319     34.905756      5.627460
# min      1000.000000     1978.000000     16.780000     -1.000000
# 25%     53500.000000     1982.000000     42.550000      3.000000
# 50%     74500.000000     1993.000000     59.950000      5.000000
# 75%     96000.000000     2004.000000     84.910000     11.000000
# max    570000.000000     2014.000000    273.830000     45.000000
#
#        Latitude(위도)  Longtitude(경도)            gdp  e_grwth(경제성장률)  \
# count  17400.000000    17400.000000   17400.000000    17400.000000
# mean      37.494002      127.060032  330970.131494        3.659925
# std        0.012002        0.017059   62803.867282        1.806509
# min       37.460256      127.018178  225613.000000       -1.900000
# 25%       37.484704      127.048360  277832.000000        2.700000
# 50%       37.493391      127.058356  335960.000000        3.500000
# 75%       37.499314      127.071381  385702.000000        4.900000
# max       37.533197      127.103555  446835.000000        7.400000
#
#        Seoul_l.rate(지가상승률)  house_rate(담보대출금리)  ...  dis_hospital(종합 병원과의 거리)  \
# count         17400.000000        17400.000000  ...              17400.000000
# mean              0.064492            6.054785  ...               1063.010719
# std               0.322120            0.607412  ...                523.568572
# min              -2.642750            5.263300  ...                 41.632692
# 25%               0.001632            5.499746  ...                635.176776
# 50%               0.016252            5.883320  ...                975.124492
# 75%               0.099044            6.576878  ...               1459.461217
# max               0.624673            7.415442  ...               3470.829811
#
#        dis_museum(국립 박물관과의 거리)  dis_subway(지하철역과의 거리)  brand_r(유명 아파트 브랜드순)  \
# count             17400.000000           17400.000000          17400.000000
# mean                985.858326             677.704437              1.147816
# std                 374.407888             394.313279              3.256703
# min                  87.490136              47.486971              0.000000
# 25%                 693.430670             318.596967              0.000000
# 50%                1032.477721             579.455311              0.000000
# 75%                1220.076628             899.616370              0.000000
# max                3323.864542            2559.068365             15.000000
#
#         n_home(세대수)    n_dong(동수)  Yongpae(용적률)   Gunpae(건폐율)  Highest(최고층)  \
# count  17400.000000  17400.000000  16137.000000  15771.000000  17400.000000
# mean    1724.199713     30.414713    251.880771     24.703887     13.693218
# std     1852.886244     42.795932    209.698580     15.030962      7.558171
# min        9.000000      1.000000     72.000000     12.000000      4.000000
# 25%      206.000000      2.000000     80.000000     16.000000      5.000000
# 50%      900.000000      8.000000    223.000000     19.000000     14.000000
# 75%     2840.000000     34.000000    285.000000     26.000000     21.000000
# max     5040.000000    124.000000   2435.000000    204.000000     46.000000
#
#         Lowest(최저층)
# count  17400.000000
# mean      11.013908
# std        5.629246
# min        3.000000
# 25%        5.000000
# 50%       12.000000
# 75%       15.000000
# max       26.000000
#
# [8 rows x 24 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17400 entries, 0 to 17399
# Data columns (total 29 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   aptnm(아파트 이름)              17400 non-null  object
#  1   yyyyqrt(거래년도 분기별)          17400 non-null  object
#  2   price(가격)                  17400 non-null  float64
#  3   con_year(건축년도)             17400 non-null  float64
#  4   dong(동)                    17400 non-null  object
#  5   area(면적)                   17400 non-null  float64
#  6   floor(층수)                  17400 non-null  float64
#  7   Latitude(위도)               17400 non-null  float64
#  8   Longtitude(경도)             17400 non-null  float64
#  9   gdp                        17400 non-null  float64
#  10  e_grwth(경제성장률)             17400 non-null  float64
#  11  Seoul_l.rate(지가상승률)        17400 non-null  float64
#  12  house_rate(담보대출금리)         17400 non-null  float64
#  13  dis_park(국립 공원과의 거리)       17400 non-null  float64
#  14  dis_highschool(고등학교와의 거리)  17400 non-null  float64
#  15  dis_reconst(재개발 지역과의 거리)   17400 non-null  float64
#  16  dis_univ(대학과의 거리)          17400 non-null  float64
#  17  dis_hospital(종합 병원과의 거리)   17400 non-null  float64
#  18  dis_museum(국립 박물관과의 거리)    17400 non-null  float64
#  19  dis_subway(지하철역과의 거리)      17400 non-null  float64
#  20  brand_r(유명 아파트 브랜드순)       17400 non-null  float64
#  21  n_home(세대수)                17400 non-null  float64
#  22  n_dong(동수)                 17400 non-null  float64
#  23  parking_per(세대별 주차장수)      17400 non-null  object
#  24  Heater(난방 시스템)             17400 non-null  object
#  25  Yongpae(용적률)               16137 non-null  float64
#  26  Gunpae(건폐율)                15771 non-null  float64
#  27  Highest(최고층)               17400 non-null  float64
#  28  Lowest(최저층)                17400 non-null  float64
# dtypes: float64(24), object(5)
# memory usage: 3.8+ MB

# %%
# noused codes
df['yyyyqrt(거래년도 분기별)'].unique()
# Out:
# array(['2006Q1', '2006Q2', '2006Q3', '2006Q4', '2007Q1', '2007Q2',
#        '2007Q3', '2007Q4', '2008Q1', '2008Q2', '2008Q3', '2008Q4',
#        '2009Q1', '2009Q2', '2009Q3', '2009Q4', '2010Q1', '2010Q2',
#        '2010Q3', '2010Q4', '2011Q1', '2011Q2', '2011Q3', '2011Q4',
#        '2012Q1', '2012Q2', '2012Q3', '2012Q4', '2013Q1', '2013Q2',
#        '2013Q3', '2013Q4', '2014Q1', '2014Q2', '2014Q3', '2014Q4',
#        '2015Q1', '2015Q2', '2015Q3', '2015Q4', '2016Q1', '2016Q2',
#        '2016Q3', '2016Q4', '2017Q1', '2017Q2', '2017Q3'], dtype=object)

# %% [markdown]
# ## Data Cleaning

# %%
# Checking missing cells
df[df['Yongpae(용적률)'].isnull()].head()
# Out:
#     aptnm(아파트 이름) yyyyqrt(거래년도 분기별)  price(가격)  con_year(건축년도) dong(동)  \
# 399       개포주공6단지            2006Q1    77100.0          1983.0     개포동
# 400       개포주공6단지            2006Q1    60600.0          1983.0     개포동
# 401       개포주공6단지            2006Q1    49000.0          1983.0     개포동
# 402       개포주공6단지            2006Q1    59400.0          1983.0     개포동
# 403       개포주공6단지            2006Q1    59500.0          1983.0     개포동
#
#      area(면적)  floor(층수)  Latitude(위도)  Longtitude(경도)       gdp  ...  \
# 399     73.02       10.0     37.478407      127.061375  225613.0  ...
# 400     60.13       14.0     37.494581      127.075275  225613.0  ...
# 401     53.06       13.0     37.484335      127.071381  225613.0  ...
# 402     60.13        2.0     37.484609      127.067275  225613.0  ...
# 403     60.13       14.0     37.478407      127.061375  225613.0  ...
#
#      dis_subway(지하철역과의 거리)  brand_r(유명 아파트 브랜드순)  n_home(세대수)  n_dong(동수)  \
# 399            1486.178329                   0.0       1060.0         9.0
# 400             316.902800                   0.0       1060.0         9.0
# 401            1155.513971                   0.0       1060.0         9.0
# 402            1160.598717                   0.0       1060.0         9.0
# 403            1486.178329                   0.0       1060.0         9.0
#
#      parking_per(세대별 주차장수)  Heater(난방 시스템)  Yongpae(용적률)  Gunpae(건폐율)  \
# 399                   0.28            중앙난방           NaN          NaN
# 400                   0.28            중앙난방           NaN          NaN
# 401                   0.28            중앙난방           NaN          NaN
# 402                   0.28            중앙난방           NaN          NaN
# 403                   0.28            중앙난방           NaN          NaN
#
#      Highest(최고층)  Lowest(최저층)
# 399          15.0         13.0
# 400          15.0         13.0
# 401          15.0         13.0
# 402          15.0         13.0
# 403          15.0         13.0
#
# [5 rows x 29 columns]

# %%
df['Yongpae(용적률)']=df['Yongpae(용적률)'].replace(np.nan,df['Yongpae(용적률)'].mean())
df['Gunpae(건폐율)']=df['Gunpae(건폐율)'].replace(np.nan,df['Gunpae(건폐율)'].mean())

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17400 entries, 0 to 17399
# Data columns (total 29 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   aptnm(아파트 이름)              17400 non-null  object
#  1   yyyyqrt(거래년도 분기별)          17400 non-null  object
#  2   price(가격)                  17400 non-null  float64
#  3   con_year(건축년도)             17400 non-null  float64
#  4   dong(동)                    17400 non-null  object
#  5   area(면적)                   17400 non-null  float64
#  6   floor(층수)                  17400 non-null  float64
#  7   Latitude(위도)               17400 non-null  float64
#  8   Longtitude(경도)             17400 non-null  float64
#  9   gdp                        17400 non-null  float64
#  10  e_grwth(경제성장률)             17400 non-null  float64
#  11  Seoul_l.rate(지가상승률)        17400 non-null  float64
#  12  house_rate(담보대출금리)         17400 non-null  float64
#  13  dis_park(국립 공원과의 거리)       17400 non-null  float64
#  14  dis_highschool(고등학교와의 거리)  17400 non-null  float64
#  15  dis_reconst(재개발 지역과의 거리)   17400 non-null  float64
#  16  dis_univ(대학과의 거리)          17400 non-null  float64
#  17  dis_hospital(종합 병원과의 거리)   17400 non-null  float64
#  18  dis_museum(국립 박물관과의 거리)    17400 non-null  float64
#  19  dis_subway(지하철역과의 거리)      17400 non-null  float64
#  20  brand_r(유명 아파트 브랜드순)       17400 non-null  float64
#  21  n_home(세대수)                17400 non-null  float64
#  22  n_dong(동수)                 17400 non-null  float64
#  23  parking_per(세대별 주차장수)      17400 non-null  object
#  24  Heater(난방 시스템)             17400 non-null  object
#  25  Yongpae(용적률)               17400 non-null  float64
#  26  Gunpae(건폐율)                17400 non-null  float64
#  27  Highest(최고층)               17400 non-null  float64
#  28  Lowest(최저층)                17400 non-null  float64
# dtypes: float64(24), object(5)
# memory usage: 3.8+ MB

# %% [markdown]
# ## See How Data Look Like 2

# %%
df['dong(동)'].value_counts()
# Out:
# 개포동     5866
# 역삼동     3729
# 대치동     2411
# 수서동     1937
# 도곡동     1032
# 청담동      868
# 논현동      636
# 삼성동      569
# 일원동      333
# 세곡동       17
# 압구정동       2
# Name: dong(동), dtype: int64

# %%
df['yyyyqrt(거래년도 분기별)'].value_counts()
# Out:
# 2017Q1    780
# 2006Q1    703
# 2006Q3    682
# 2006Q4    670
# 2006Q2    562
# 2017Q2    537
# 2016Q3    419
# 2008Q2    416
# 2012Q4    416
# 2015Q2    405
# 2011Q3    397
# 2016Q1    389
# 2007Q4    386
# 2008Q1    385
# 2015Q3    373
# 2015Q1    370
# 2016Q2    369
# 2011Q4    367
# 2011Q1    357
# 2011Q2    353
# 2010Q1    353
# 2017Q3    352
# 2007Q2    349
# 2015Q4    348
# 2013Q3    343
# 2014Q4    336
# 2013Q2    334
# 2009Q1    325
# 2013Q1    325
# 2013Q4    323
# 2014Q1    317
# 2007Q3    315
# 2010Q4    313
# 2010Q3    310
# 2016Q4    306
# 2014Q3    304
# 2009Q2    303
# 2014Q2    298
# 2009Q3    295
# 2009Q4    280
# 2012Q2    277
# 2007Q1    270
# 2010Q2    241
# 2012Q1    238
# 2008Q3    219
# 2012Q3    204
# 2008Q4    186
# Name: yyyyqrt(거래년도 분기별), dtype: int64

# %% [markdown]
# ## Basic Methods

# %%
data1= df.loc[:,'yyyyqrt(거래년도 분기별)':'Longtitude(경도)']
data1.head()
# Out:
#   yyyyqrt(거래년도 분기별)  price(가격)  con_year(건축년도) dong(동)  area(면적)  floor(층수)  \
# 0            2006Q1     9000.0          2004.0     역삼동     17.23        7.0
# 1            2006Q1     9000.0          2004.0     역삼동     17.23        7.0
# 2            2006Q1    73000.0          1982.0     개포동     50.38        3.0
# 3            2006Q1    70000.0          1982.0     개포동     50.64        5.0
# 4            2006Q1    40000.0          1982.0     개포동     35.44        4.0
#
#    Latitude(위도)  Longtitude(경도)
# 0     37.494204      127.043545
# 1     37.494204      127.043545
# 2     37.478407      127.061375
# 3     37.484609      127.067275
# 4     37.482445      127.051278

# %%
data1= df[['yyyyqrt(거래년도 분기별)','price(가격)','dong(동)','Latitude(위도)', 'Longtitude(경도)',
           'Seoul_l.rate(지가상승률)','dis_subway(지하철역과의 거리)' ]]
data1.head()
# Out:
#   yyyyqrt(거래년도 분기별)  price(가격) dong(동)  Latitude(위도)  Longtitude(경도)  \
# 0            2006Q1     9000.0     역삼동     37.494204      127.043545
# 1            2006Q1     9000.0     역삼동     37.494204      127.043545
# 2            2006Q1    73000.0     개포동     37.478407      127.061375
# 3            2006Q1    70000.0     개포동     37.484609      127.067275
# 4            2006Q1    40000.0     개포동     37.482445      127.051278
#
#    Seoul_l.rate(지가상승률)  dis_subway(지하철역과의 거리)
# 0             0.152881             849.353653
# 1             0.152881             849.353653
# 2             0.152881            1486.178329
# 3             0.152881            1160.598717
# 4             0.152881             650.325555

# %%
data1.tail()
# Out:
#       yyyyqrt(거래년도 분기별)  price(가격) dong(동)  Latitude(위도)  Longtitude(경도)  \
# 17395            2017Q3   179000.0     청담동     37.526956      127.053126
# 17396            2017Q3   122500.0     역삼동     37.496260      127.046404
# 17397            2017Q3    64000.0     역삼동     37.491379      127.034880
# 17398            2017Q3   170000.0     청담동     37.524675      127.056226
# 17399            2017Q3   170000.0     청담동     37.524675      127.056226
#
#        Seoul_l.rate(지가상승률)  dis_subway(지하철역과의 거리)
# 17395             0.069818             874.719438
# 17396             0.069818             944.717800
# 17397             0.069818             812.764336
# 17398             0.069818             717.729425
# 17399             0.069818             717.729425

# %% [markdown]
# # 2️⃣ Real-Estate Time Series Data
# ## Exercise(2) - Visualize the Data Considering Its Location

# %%
dong = ['Chungdam', 'Apgujeong', 'Dogok', 'Samsung','Daechi','Gaepo','Yeocksam', 'Suseo']
lon=[127.0487,127.0303,127.0438,127.0565,127.0611,127.0609,127.0374,127.1052]
lat=[37.5232,37.5317,37.4898,37.5140,37.4995,37.4790,37.4999,37.4890]
data = {'Dong':dong,'Lat':lat,'Lng' : lon}
dong_data=pd.DataFrame(data=data)
dong_data
# Out:
#         Dong      Lat       Lng
# 0   Chungdam  37.5232  127.0487
# 1  Apgujeong  37.5317  127.0303
# 2      Dogok  37.4898  127.0438
# 3    Samsung  37.5140  127.0565
# 4     Daechi  37.4995  127.0611
# 5      Gaepo  37.4790  127.0609
# 6   Yeocksam  37.4999  127.0374
# 7      Suseo  37.4890  127.1052

# %%
# Location plot (Spatial information)
plt.figure(figsize=(8, 5))
plt.scatter(data1['Longtitude(경도)'],data1['Latitude(위도)'],alpha=0.1) # data plot

for i in range(8): # Marking areas
    plt.text(dong_data['Lng'][i], dong_data['Lat'][i],dong_data['Dong'][i],fontsize=12)
plt.scatter(dong_data['Lng'], dong_data['Lat'],edgecolors="black",c="None",s=2500,alpha=0.3)  
plt.xlabel("Longitude")
plt.ylabel("Latitude")
# Out:
# Text(0, 0.5, 'Latitude')

# %%
# Changing the names of columns
data2=data1.copy()
data2.columns=['yearqrt', 'price', 'dong','Lat', 'Lng','rate','station_dist']
data2
# Out:
#       yearqrt     price dong        Lat         Lng      rate  station_dist
# 0      2006Q1    9000.0  역삼동  37.494204  127.043545  0.152881    849.353653
# 1      2006Q1    9000.0  역삼동  37.494204  127.043545  0.152881    849.353653
# 2      2006Q1   73000.0  개포동  37.478407  127.061375  0.152881   1486.178329
# 3      2006Q1   70000.0  개포동  37.484609  127.067275  0.152881   1160.598717
# 4      2006Q1   40000.0  개포동  37.482445  127.051278  0.152881    650.325555
# ...       ...       ...  ...        ...         ...       ...           ...
# 17395  2017Q3  179000.0  청담동  37.526956  127.053126  0.069818    874.719438
# 17396  2017Q3  122500.0  역삼동  37.496260  127.046404  0.069818    944.717800
# 17397  2017Q3   64000.0  역삼동  37.491379  127.034880  0.069818    812.764336
# 17398  2017Q3  170000.0  청담동  37.524675  127.056226  0.069818    717.729425
# 17399  2017Q3  170000.0  청담동  37.524675  127.056226  0.069818    717.729425
#
# [17400 rows x 7 columns]

# %%
# visualize price at 2006 and 2017
plt.figure(figsize=(25, 8))

tp=data2[data2['yearqrt'].str.contains("2006Q")]
plt.subplot(1,2,1) # price plot
plt.scatter(x=tp["Lng"], y=tp["Lat"], c=tp["price"],s=200, cmap=plt.cm.Reds)
plt.colorbar(label='color')
for i in range(8): # Marking areas
    plt.text(dong_data['Lng'][i], dong_data['Lat'][i],dong_data['Dong'][i],fontsize=12)
plt.scatter(dong_data['Lng'], dong_data['Lat'],edgecolors="black",c="None",s=15000,alpha=0.3)  
plt.title("2006"); plt.xlabel("Longitude"); plt.ylabel("Latitude");


tp=data2[data2['yearqrt'].str.contains("2017Q")]
plt.subplot(1,2,2)  # price plot
plt.scatter(x=tp["Lng"], y=tp["Lat"], c=tp["price"], s=200,cmap=plt.cm.Reds)
plt.colorbar(label='color')
for i in range(8): # Marking areas
    plt.text(dong_data['Lng'][i], dong_data['Lat'][i],dong_data['Dong'][i],fontsize=12)
plt.scatter(dong_data['Lng'], dong_data['Lat'],edgecolors="black",c="None",s=15000,alpha=0.3)  
plt.title("2017"); plt.xlabel("Longitude"); plt.ylabel("Latitude");

# %%
data_gaepo=data2[data2['dong']=='개포동']
data_gaepo.head()
# Out:
#   yearqrt    price dong        Lat         Lng      rate  station_dist
# 2  2006Q1  73000.0  개포동  37.478407  127.061375  0.152881   1486.178329
# 3  2006Q1  70000.0  개포동  37.484609  127.067275  0.152881   1160.598717
# 4  2006Q1  40000.0  개포동  37.482445  127.051278  0.152881    650.325555
# 5  2006Q1  56000.0  개포동  37.478407  127.061375  0.152881   1486.178329
# 6  2006Q1  40500.0  개포동  37.494581  127.075275  0.152881    316.902800

# %%
data_gaepo_time=data_gaepo.groupby('yearqrt').mean()  
data_gaepo_time.head()
# Out:
#                 price        Lat         Lng      rate  station_dist
# yearqrt
# 2006Q1   66954.968288  37.483163  127.063829  0.152881   1106.719865
# 2006Q2   69240.408163  37.484935  127.066870  0.430146   1009.206136
# 2006Q3   71064.128440  37.484071  127.063688  0.367231   1060.919660
# 2006Q4   86538.140704  37.484502  127.065871  0.624673   1033.040965
# 2007Q1   79064.285714  37.487090  127.068583  0.100708    846.666678

# %%
plt.figure(figsize=(20,8))
plt.title("Gaepo")
plt.plot(data_gaepo_time['price'])
plt.show()

# %% [markdown]
# ## Exercise(3) - Each Dong's Average Price Changes Over Time

# %%
#for Korean Class (printing korean words)
import matplotlib.font_manager as fm

# print korean fonts that you have
# font_list = [font.name for font in fm.fontManager.ttflist]
#print(font_list)
plt.rcParams['font.family'] = 'Malgun Gothic'

import matplotlib # For broken '-' sign
matplotlib.rcParams['axes.unicode_minus'] = False

# %%
# 예시
mask = df[df['dong(동)']== '역삼동']
mask = mask.groupby('yyyyqrt(거래년도 분기별)').mean()
mask
# Out:
#                        price(가격)  con_year(건축년도)   area(면적)  floor(층수)  \
# yyyyqrt(거래년도 분기별)
# 2006Q1              55557.471264     2001.827586  72.832874  10.218391
# 2006Q2              45610.355932     2001.644068  72.245424  10.152542
# 2006Q3              51821.428571     2002.107143  82.117500   6.178571
# 2006Q4              62745.482143     2002.160714  72.973750  10.383929
# 2007Q1              24471.739130     2002.652174  44.459130   8.304348
# 2007Q2              31627.027027     2003.486486  59.829459   7.108108
# 2007Q3              43451.515152     2003.030303  64.943636  10.303030
# 2007Q4              42256.578947     2002.026316  64.048947  12.000000
# 2008Q1              37975.000000     2002.439394  56.864242  10.515152
# 2008Q2              34589.081633     2002.714286  51.612449  10.081633
# 2008Q3              33354.947368     2003.078947  50.977895   8.763158
# 2008Q4              54529.411765     2003.941176  67.494118  10.764706
# 2009Q1              59560.588235     2003.929412  67.000000  12.047059
# 2009Q2              66746.923077     2003.769231  69.470077  10.700000
# 2009Q3              57960.396825     2003.428571  63.740079  10.896825
# 2009Q4              64255.932203     2003.661017  71.826949  10.508475
# 2010Q1              59364.086957     2003.231884  70.920725  10.362319
# 2010Q2              50428.409091     2002.750000  56.555682  11.704545
# 2010Q3              58434.545455     2002.418182  68.109091   9.709091
# 2010Q4              60652.205882     2004.735294  68.631838   9.875000
# 2011Q1              58332.689076     2003.042017  65.862269  10.831933
# 2011Q2              52414.444444     2002.422222  65.342222   9.111111
# 2011Q3              66713.567164     2003.940299  71.190896  10.611940
# 2011Q4              72049.019608     2003.764706  81.233922   9.960784
# 2012Q1              70717.187500     2003.656250  79.374687  10.656250
# 2012Q2              56701.515152     2003.969697  62.235758  10.909091
# 2012Q3              55480.434783     2002.739130  64.585652   9.217391
# 2012Q4              68284.375000     2004.312500  78.525000  11.354167
# 2013Q1              64340.000000     2004.485714  74.143143  10.571429
# 2013Q2              64734.057971     2004.811594  69.606812  10.536232
# 2013Q3              67175.000000     2003.977273  73.975000   9.750000
# 2013Q4              74058.208955     2004.044776  79.134627   9.641791
# 2014Q1              67784.536082     2003.804124  70.325258  11.010309
# 2014Q2              64434.821429     2003.303571  73.144821   8.785714
# 2014Q3              79607.280702     2003.921053  81.544649   9.666667
# 2014Q4              74062.087912     2003.923077  78.353846   9.648352
# 2015Q1              74886.507937     2003.563492  77.533333   9.373016
# 2015Q2              81998.888889     2004.103704  81.404074   9.511111
# 2015Q3              74232.608696     2002.623188  74.636232  11.202899
# 2015Q4              82976.666667     2003.880000  81.941467   9.733333
# 2016Q1              70533.333333     2002.750000  67.289444   8.555556
# 2016Q2              90639.406780     2004.008475  83.161186  10.864407
# 2016Q3              91170.661157     2003.909091  83.636694  10.214876
# 2016Q4              89699.275362     2004.086957  79.258116  10.173913
# 2017Q1              90780.833333     2003.983333  80.739167  10.533333
# 2017Q2              99435.526316     2004.493421  86.855395   9.697368
# 2017Q3             110281.318681     2004.230769  95.953516   9.494505
#
#                    Latitude(위도)  Longtitude(경도)       gdp  e_grwth(경제성장률)  \
# yyyyqrt(거래년도 분기별)
# 2006Q1                37.498870      127.045815  225613.0             6.3
# 2006Q2                37.498406      127.043247  237948.0             4.7
# 2006Q3                37.497855      127.042191  246142.0             5.1
# 2006Q4                37.498855      127.044124  256382.0             4.8
# 2007Q1                37.496537      127.043322  240439.0             4.7
# 2007Q2                37.498196      127.041430  257743.0             5.6
# 2007Q3                37.498825      127.040854  264988.0             5.1
# 2007Q4                37.500297      127.040609  280088.0             6.3
# 2008Q1                37.500025      127.041510  258378.0             5.5
# 2008Q2                37.499970      127.041852  277832.0             4.1
# 2008Q3                37.499232      127.041637  283402.0             3.9
# 2008Q4                37.496264      127.046209  284880.0            -1.6
# 2009Q1                37.498423      127.044326  263587.0            -1.9
# 2009Q2                37.499091      127.044431  285531.0            -1.1
# 2009Q3                37.499280      127.045009  296487.0             0.9
# 2009Q4                37.499032      127.044166  306103.0             4.8
# 2010Q1                37.499021      127.044504  291583.0             7.2
# 2010Q2                37.499195      127.044059  316129.0             7.4
# 2010Q3                37.498824      127.045132  321990.0             5.4
# 2010Q4                37.497873      127.045458  335607.0             6.0
# 2011Q1                37.498766      127.044661  312181.0             4.9
# 2011Q2                37.497492      127.043014  330892.0             3.6
# 2011Q3                37.497795      127.044280  337411.0             3.3
# 2011Q4                37.498237      127.042023  352197.0             3.1
# 2012Q1                37.498909      127.044722  327407.0             2.6
# 2012Q2                37.497513      127.045539  343894.0             2.4
# 2012Q3                37.498373      127.044388  347443.0             2.1
# 2012Q4                37.497912      127.044459  358713.0             2.1
# 2013Q1                37.496707      127.046761  335960.0             2.1
# 2013Q2                37.498480      127.043053  356630.0             2.7
# 2013Q3                37.497967      127.045986  363827.0             3.2
# 2013Q4                37.498580      127.044749  373027.0             3.5
# 2014Q1                37.498631      127.046276  353743.0             3.9
# 2014Q2                37.498021      127.043959  370186.0             3.5
# 2014Q3                37.497867      127.045498  376447.0             3.4
# 2014Q4                37.498068      127.044182  385702.0             2.7
# 2015Q1                37.497423      127.045263  369947.0             2.6
# 2015Q2                37.497786      127.045118  389173.0             2.4
# 2015Q3                37.497554      127.044362  398476.0             3.0
# 2015Q4                37.498349      127.045642  406526.0             3.2
# 2016Q1                37.498655      127.043965  387353.0             3.0
# 2016Q2                37.497946      127.046244  409958.0             3.5
# 2016Q3                37.498088      127.045547  415025.0             2.7
# 2016Q4                37.498017      127.043997  425084.0             2.6
# 2017Q1                37.497658      127.044535  406309.0             2.9
# 2017Q2                37.498126      127.045410  431027.0             2.8
# 2017Q3                37.498244      127.044601  446835.0             3.8
#
#                    Seoul_l.rate(지가상승률)  house_rate(담보대출금리)  ...  \
# yyyyqrt(거래년도 분기별)                                           ...
# 2006Q1                        0.152881            5.559495  ...
# 2006Q2                        0.430146            5.486247  ...
# 2006Q3                        0.367231            5.429957  ...
# 2006Q4                        0.624673            5.436579  ...
# 2007Q1                        0.100708            5.557577  ...
# 2007Q2                        0.041493            5.707583  ...
# 2007Q3                        0.082893            5.806539  ...
# 2007Q4                        0.218588            5.772916  ...
# 2008Q1                        0.209861            5.716543  ...
# 2008Q2                        0.351297            5.752641  ...
# 2008Q3                        0.109589            5.890836  ...
# 2008Q4                       -2.642750            6.055300  ...
# 2009Q1                       -0.011379            6.163212  ...
# 2009Q2                        0.011595            6.169930  ...
# 2009Q3                        0.065216            6.166600  ...
# 2009Q4                        0.022254            6.143304  ...
# 2010Q1                        0.016252            6.179833  ...
# 2010Q2                       -0.000008            6.249164  ...
# 2010Q3                       -0.000571            6.378976  ...
# 2010Q4                       -0.000392            6.482908  ...
# 2011Q1                        0.002406            6.553271  ...
# 2011Q2                        0.000737            6.662017  ...
# 2011Q3                        0.000160            6.837066  ...
# 2011Q4                        0.000070            6.881731  ...
# 2012Q1                        0.000131            6.831128  ...
# 2012Q2                        0.000213            6.739862  ...
# 2012Q3                       -0.000571            6.763183  ...
# 2012Q4                       -0.000005            6.786655  ...
# 2013Q1                       -0.000426            6.826344  ...
# 2013Q2                        0.001632            6.948151  ...
# 2013Q3                        0.000594            7.108627  ...
# 2013Q4                        0.009544            7.327797  ...
# 2014Q1                        0.016191            7.415442  ...
# 2014Q2                        0.008873            7.262287  ...
# 2014Q3                        0.015458            6.576878  ...
# 2014Q4                        0.012396            5.908527  ...
# 2015Q1                        0.008581            5.478944  ...
# 2015Q2                        0.016822            5.369733  ...
# 2015Q3                        0.016538            5.326129  ...
# 2015Q4                        0.016870            5.266614  ...
# 2016Q1                        0.008716            5.263300  ...
# 2016Q2                        0.017696            5.329304  ...
# 2016Q3                        0.026315            5.499746  ...
# 2016Q4                        0.023280            5.703500  ...
# 2017Q1                        0.015810            5.846402  ...
# 2017Q2                        0.099044            5.889983  ...
# 2017Q3                        0.069818            5.883320  ...
#
#                    dis_hospital(종합 병원과의 거리)  dis_museum(국립 박물관과의 거리)  \
# yyyyqrt(거래년도 분기별)
# 2006Q1                           770.325211              1083.709798
# 2006Q2                           760.141127              1238.204177
# 2006Q3                           761.590138              1175.642077
# 2006Q4                           828.104247              1152.101067
# 2007Q1                           875.483552              1252.210665
# 2007Q2                           906.436550              1170.542908
# 2007Q3                           980.355832              1158.674635
# 2007Q4                           872.926676              1151.547291
# 2008Q1                           867.936299              1191.258389
# 2008Q2                           869.799497              1204.007714
# 2008Q3                           937.575978              1194.023229
# 2008Q4                           945.918482              1049.507248
# 2009Q1                           807.817052              1130.242291
# 2009Q2                           806.660522              1095.318186
# 2009Q3                           784.792789              1120.619266
# 2009Q4                           794.745879              1106.192478
# 2010Q1                           828.019634              1106.802818
# 2010Q2                           847.365219              1071.808863
# 2010Q3                           817.825762              1108.120894
# 2010Q4                           775.888295              1093.247897
# 2011Q1                           822.697164              1129.154180
# 2011Q2                           918.947519              1084.132486
# 2011Q3                           762.728160              1173.675849
# 2011Q4                           732.134941              1211.413168
# 2012Q1                           844.028784              1180.941187
# 2012Q2                           798.659169              1094.945779
# 2012Q3                           720.144391              1206.870665
# 2012Q4                           820.853031              1131.739445
# 2013Q1                           786.989314              1108.512759
# 2013Q2                           715.701998              1207.965894
# 2013Q3                           736.040066              1188.082120
# 2013Q4                           703.328785              1136.549392
# 2014Q1                           704.699399              1134.818595
# 2014Q2                           665.587746              1247.041186
# 2014Q3                           703.753527              1134.465355
# 2014Q4                           714.420075              1181.481412
# 2015Q1                           713.108147              1186.919688
# 2015Q2                           764.909720              1130.237912
# 2015Q3                           743.446561              1115.565308
# 2015Q4                           709.413449              1166.541562
# 2016Q1                           753.961631              1193.272706
# 2016Q2                           740.784526              1118.855593
# 2016Q3                           692.073510              1130.014135
# 2016Q4                           696.270882              1211.695714
# 2017Q1                           715.735350              1149.359905
# 2017Q2                           699.620555              1172.643055
# 2017Q3                           713.925567              1160.221145
#
#                    dis_subway(지하철역과의 거리)  brand_r(유명 아파트 브랜드순)  n_home(세대수)  \
# yyyyqrt(거래년도 분기별)
# 2006Q1                        604.060242              3.839080   542.988506
# 2006Q2                        620.136498              1.898305   327.169492
# 2006Q3                        680.588813              2.500000   283.285714
# 2006Q4                        561.186306              3.410714   428.991071
# 2007Q1                        664.389531              0.434783   182.347826
# 2007Q2                        582.278327              0.432432   127.108108
# 2007Q3                        531.045657              1.818182   298.909091
# 2007Q4                        547.072410              1.210526   299.868421
# 2008Q1                        546.224634              1.181818   238.106061
# 2008Q2                        520.333749              1.612245   288.081633
# 2008Q3                        537.260113              1.052632   203.868421
# 2008Q4                        686.050753              5.176471   398.117647
# 2009Q1                        634.806892              6.000000   574.541176
# 2009Q2                        586.279564              6.276923   517.769231
# 2009Q3                        602.259300              5.269841   490.746032
# 2009Q4                        644.739862              5.152542   489.593220
# 2010Q1                        591.636499              3.971014   392.637681
# 2010Q2                        595.278713              4.136364   464.181818
# 2010Q3                        607.192190              4.581818   470.800000
# 2010Q4                        631.450190              4.514706   405.860294
# 2011Q1                        576.771341              3.697479   430.352941
# 2011Q2                        626.636919              2.888889   344.977778
# 2011Q3                        641.159395              5.014925   493.253731
# 2011Q4                        638.518015              4.941176   448.960784
# 2012Q1                        595.006244              4.937500   460.156250
# 2012Q2                        665.445403              4.060606   541.969697
# 2012Q3                        664.228745              4.869565   444.217391
# 2012Q4                        643.596978              4.875000   498.375000
# 2013Q1                        707.905689              5.771429   513.342857
# 2013Q2                        640.796108              5.884058   540.231884
# 2013Q3                        674.232313              6.045455   570.409091
# 2013Q4                        660.888501              6.208955   513.343284
# 2014Q1                        653.670928              6.453608   593.340206
# 2014Q2                        639.668586              4.821429   432.285714
# 2014Q3                        672.788434              6.526316   480.429825
# 2014Q4                        661.669237              4.901099   417.483516
# 2015Q1                        673.713446              5.507937   483.452381
# 2015Q2                        667.383319              5.437037   449.051852
# 2015Q3                        656.118579              4.231884   434.173913
# 2015Q4                        661.707332              4.586667   378.613333
# 2016Q1                        636.650951              5.055556   514.055556
# 2016Q2                        657.527591              6.169492   540.296610
# 2016Q3                        683.738410              5.404959   472.851240
# 2016Q4                        658.584648              5.797101   494.304348
# 2017Q1                        689.392746              6.100000   501.916667
# 2017Q2                        659.274081              6.394737   518.210526
# 2017Q3                        661.919621              6.131868   429.648352
#
#                    n_dong(동수)  Yongpae(용적률)  Gunpae(건폐율)  Highest(최고층)  \
# yyyyqrt(거래년도 분기별)
# 2006Q1               6.000000    386.136561    29.835677     20.655172
# 2006Q2               3.338983    469.050847    38.118644     17.559322
# 2006Q3               3.392857    328.250000    35.714286     14.714286
# 2006Q4               4.776786    368.848214    29.857143     19.446429
# 2007Q1               1.739130    555.565217    50.391304     14.565217
# 2007Q2               1.540541    509.996778    49.046051     13.243243
# 2007Q3               2.909091    648.575758    46.030303     19.454545
# 2007Q4               2.763158    574.026316    43.500000     19.315789
# 2008Q1               2.409091    585.121212    47.348485     17.530303
# 2008Q2               2.897959    582.663265    46.979592     17.775510
# 2008Q3               2.263158    527.342105    47.842105     15.342105
# 2008Q4               4.941176    437.588235    37.117647     18.411765
# 2009Q1               6.811765    426.611765    30.352941     21.129412
# 2009Q2               6.269231    427.415385    30.700000     21.823077
# 2009Q3               5.777778    487.436508    36.087302     20.642857
# 2009Q4               5.949153    401.930183    31.401761     19.966102
# 2010Q1               4.492754    461.289855    36.202899     19.318841
# 2010Q2               5.000000    570.977273    39.409091     21.318182
# 2010Q3               5.272727    476.618182    34.090909     21.145455
# 2010Q4               5.117647    401.227941    30.823529     19.191176
# 2011Q1               4.865546    458.974790    34.773109     20.084034
# 2011Q2               3.844444    479.219573    37.348975     18.444444
# 2011Q3               5.880597    415.283582    31.343284     19.955224
# 2011Q4               5.647059    334.941176    29.588235     18.098039
# 2012Q1               5.468750    432.125000    30.718750     21.750000
# 2012Q2               6.151515    460.939394    33.787879     20.333333
# 2012Q3               5.347826    389.695652    32.304348     18.956522
# 2012Q4               5.958333    410.833333    30.916667     20.395833
# 2013Q1               6.457143    374.057143    29.914286     19.771429
# 2013Q2               6.753623    392.362319    28.753623     20.492754
# 2013Q3               6.977273    356.545455    27.272727     19.909091
# 2013Q4               6.641791    330.671642    26.791045     20.656716
# 2014Q1               7.134021    388.432990    28.082474     21.247423
# 2014Q2               5.303571    402.160714    36.482143     18.392857
# 2014Q3               6.236842    346.543860    26.000000     21.184211
# 2014Q4               5.362637    378.921767    30.930812     19.802198
# 2015Q1               6.000000    359.666667    30.063492     19.563492
# 2015Q2               5.651852    380.265783    29.286695     20.481481
# 2015Q3               4.985507    445.826087    33.086957     21.144928
# 2015Q4               4.906667    371.558410    31.342718     19.146667
# 2016Q1               6.083333    384.055556    28.166667     20.361111
# 2016Q2               6.737288    338.957627    25.644068     21.084746
# 2016Q3               6.090909    329.892562    25.768595     20.628099
# 2016Q4               6.217391    352.391304    28.463768     20.521739
# 2017Q1               6.350000    395.433333    29.300000     20.950000
# 2017Q2               6.763158    331.116852    24.923735     21.171053
# 2017Q3               5.824176    361.305072    29.356129     20.120879
#
#                    Lowest(최저층)
# yyyyqrt(거래년도 분기별)
# 2006Q1               14.988506
# 2006Q2               14.271186
# 2006Q3               10.571429
# 2006Q4               14.562500
# 2007Q1               13.434783
# 2007Q2               12.270270
# 2007Q3               16.818182
# 2007Q4               16.868421
# 2008Q1               15.181818
# 2008Q2               15.581633
# 2008Q3               13.631579
# 2008Q4               13.117647
# 2009Q1               14.847059
# 2009Q2               15.192308
# 2009Q3               15.380952
# 2009Q4               14.542373
# 2010Q1               14.884058
# 2010Q2               16.909091
# 2010Q3               16.000000
# 2010Q4               14.110294
# 2011Q1               14.621849
# 2011Q2               14.955556
# 2011Q3               13.492537
# 2011Q4               12.215686
# 2012Q1               14.656250
# 2012Q2               14.090909
# 2012Q3               13.478261
# 2012Q4               14.187500
# 2013Q1               12.685714
# 2013Q2               13.115942
# 2013Q3               12.818182
# 2013Q4               12.731343
# 2014Q1               14.505155
# 2014Q2               12.589286
# 2014Q3               13.675439
# 2014Q4               13.318681
# 2015Q1               12.658730
# 2015Q2               13.533333
# 2015Q3               15.391304
# 2015Q4               12.773333
# 2016Q1               14.500000
# 2016Q2               13.525424
# 2016Q3               13.107438
# 2016Q4               13.333333
# 2017Q1               13.550000
# 2017Q2               13.000000
# 2017Q3               13.054945
#
# [47 rows x 24 columns]

# %%
dong=df['dong(동)'].unique()
plt.figure(figsize=(50,100))
count=1
for i in dong:
    mask = df[df['dong(동)']== i]
    m = mask.groupby('yyyyqrt(거래년도 분기별)').mean()
    plt.subplot(6,2,count)
    plt.plot(m['price(가격)'],linewidth = 3.0)
    plt.title(i,fontsize = 80)
    plt.yticks(fontsize = 50)
    count=count+1
plt.show()
# Out:
# /Users/parkgeonwoo/miniconda3/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 50669 (\N{HANGUL SYLLABLE YEOG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/parkgeonwoo/miniconda3/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 49340 (\N{HANGUL SYLLABLE SAM}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/parkgeonwoo/miniconda3/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 46041 (\N{HANGUL SYLLABLE DONG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/parkgeonwoo/miniconda3/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 44060 (\N{HANGUL SYLLABLE GAE}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/parkgeonwoo/miniconda3/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 54252 (\N{HANGUL SYLLABLE PO}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/parkgeonwoo/miniconda3/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 52397 (\N{HANGUL SYLLABLE CEONG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/parkgeonwoo/miniconda3/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 45812 (\N{HANGUL SYLLABLE DAM}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/parkgeonwoo/miniconda3/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 45824 (\N{HANGUL SYLLABLE DAE}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/parkgeonwoo/miniconda3/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 52824 (\N{HANGUL SYLLABLE CI}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/parkgeonwoo/miniconda3/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 49457 (\N{HANGUL SYLLABLE SEONG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/parkgeonwoo/miniconda3/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 45436 (\N{HANGUL SYLLABLE NON}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/parkgeonwoo/miniconda3/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 54788 (\N{HANGUL SYLLABLE HYEON}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/parkgeonwoo/miniconda3/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 46020 (\N{HANGUL SYLLABLE DO}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/parkgeonwoo/miniconda3/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 44257 (\N{HANGUL SYLLABLE GOG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/parkgeonwoo/miniconda3/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 49688 (\N{HANGUL SYLLABLE SU}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/parkgeonwoo/miniconda3/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 49436 (\N{HANGUL SYLLABLE SEO}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/parkgeonwoo/miniconda3/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 51068 (\N{HANGUL SYLLABLE IL}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/parkgeonwoo/miniconda3/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 50896 (\N{HANGUL SYLLABLE WEON}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/parkgeonwoo/miniconda3/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 50517 (\N{HANGUL SYLLABLE AB}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/parkgeonwoo/miniconda3/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 44396 (\N{HANGUL SYLLABLE GU}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/parkgeonwoo/miniconda3/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 51221 (\N{HANGUL SYLLABLE JEONG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/parkgeonwoo/miniconda3/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 49464 (\N{HANGUL SYLLABLE SE}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %% [markdown]
# ## Exercise(4) - Simple Smoothing Using 5-MA

# %%
dong_col=[]
for i in dong:
    tmp=df[df['dong(동)']==i]
    tp=tmp.groupby('yyyyqrt(거래년도 분기별)').mean()
    print(i, ' : ', len(tp), end=' ')
    dong_col.append(i)
    print('\n')
# Out:
# 역삼동  :  47
#
# 개포동  :  47
#
# 청담동  :  47
#
# 대치동  :  46
#
# 삼성동  :  47
#
# 논현동  :  38
#
# 도곡동  :  32
#
# 수서동  :  32
#
# 일원동  :  32
#
# 압구정동  :  1
#
# 세곡동  :  6

# %%
plt.figure(figsize=(50,100))
count=1; date=[];
nMA = 2 # number of Pre(or post) samples to average
for i in dong:
    mask=df[df['dong(동)']==i]
    m=mask.groupby('yyyyqrt(거래년도 분기별)').mean().copy()
    ls=[]
    for j in range(nMA,len(m)-nMA): # Averaging 5 samples
        ls.append(m['price(가격)'].iloc[j-nMA:j+nMA].mean())
    
    d=pd.DataFrame({'Time' : m.index.values[nMA:len(m)-nMA], 'Mean_Price' : ls })
    plt.subplot(6,2,count)
    plt.title(i,fontsize=80); plt.yticks(fontsize = 50)
    plt.plot(d['Time'],d['Mean_Price'],linewidth=3.0)
    count=count+1
# Out:
# /Users/parkgeonwoo/miniconda3/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 50669 (\N{HANGUL SYLLABLE YEOG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/parkgeonwoo/miniconda3/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 49340 (\N{HANGUL SYLLABLE SAM}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/parkgeonwoo/miniconda3/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 46041 (\N{HANGUL SYLLABLE DONG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/parkgeonwoo/miniconda3/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 44060 (\N{HANGUL SYLLABLE GAE}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/parkgeonwoo/miniconda3/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 54252 (\N{HANGUL SYLLABLE PO}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/parkgeonwoo/miniconda3/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 52397 (\N{HANGUL SYLLABLE CEONG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/parkgeonwoo/miniconda3/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 45812 (\N{HANGUL SYLLABLE DAM}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/parkgeonwoo/miniconda3/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 45824 (\N{HANGUL SYLLABLE DAE}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/parkgeonwoo/miniconda3/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 52824 (\N{HANGUL SYLLABLE CI}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/parkgeonwoo/miniconda3/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 49457 (\N{HANGUL SYLLABLE SEONG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/parkgeonwoo/miniconda3/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 45436 (\N{HANGUL SYLLABLE NON}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/parkgeonwoo/miniconda3/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 54788 (\N{HANGUL SYLLABLE HYEON}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/parkgeonwoo/miniconda3/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 46020 (\N{HANGUL SYLLABLE DO}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/parkgeonwoo/miniconda3/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 44257 (\N{HANGUL SYLLABLE GOG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/parkgeonwoo/miniconda3/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 49688 (\N{HANGUL SYLLABLE SU}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/parkgeonwoo/miniconda3/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 49436 (\N{HANGUL SYLLABLE SEO}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/parkgeonwoo/miniconda3/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 51068 (\N{HANGUL SYLLABLE IL}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/parkgeonwoo/miniconda3/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 50896 (\N{HANGUL SYLLABLE WEON}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/parkgeonwoo/miniconda3/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 50517 (\N{HANGUL SYLLABLE AB}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/parkgeonwoo/miniconda3/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 44396 (\N{HANGUL SYLLABLE GU}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/parkgeonwoo/miniconda3/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 51221 (\N{HANGUL SYLLABLE JEONG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/parkgeonwoo/miniconda3/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 49464 (\N{HANGUL SYLLABLE SE}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
corr=df.corr()
corr.head(15)
# Out:
#                            price(가격)  con_year(건축년도)  area(면적)  floor(층수)  \
# price(가격)                   1.000000        0.085364  0.711187   0.094599
# con_year(건축년도)              0.085364        1.000000  0.439237   0.390900
# area(면적)                    0.711187        0.439237  1.000000   0.185766
# floor(층수)                   0.094599        0.390900  0.185766   1.000000
# Latitude(위도)                0.105059        0.528441  0.434611   0.162481
# Longtitude(경도)             -0.079797       -0.428207 -0.238154  -0.162969
# gdp                         0.289566        0.017524  0.112332  -0.005394
# e_grwth(경제성장률)             -0.132575        0.018824 -0.063985  -0.014200
# Seoul_l.rate(지가상승률)        -0.044081        0.003777 -0.049426  -0.032827
# house_rate(담보대출금리)         -0.016064        0.064364  0.073215   0.096666
# dis_park(국립 공원과의 거리)        0.124167       -0.249766 -0.066577  -0.062905
# dis_highschool(고등학교와의 거리)   0.008956        0.020907  0.034017  -0.051315
# dis_reconst(재개발 지역과의 거리)   -0.217519        0.288396  0.025094   0.086767
# dis_univ(대학과의 거리)          -0.025299       -0.607955 -0.331806  -0.233695
# dis_hospital(종합 병원과의 거리)   -0.027211       -0.567171 -0.351692  -0.334654
#
#                            Latitude(위도)  Longtitude(경도)       gdp  \
# price(가격)                      0.105059       -0.079797  0.289566
# con_year(건축년도)                 0.528441       -0.428207  0.017524
# area(면적)                       0.434611       -0.238154  0.112332
# floor(층수)                      0.162481       -0.162969 -0.005394
# Latitude(위도)                   1.000000       -0.439299  0.025258
# Longtitude(경도)                -0.439299        1.000000 -0.048094
# gdp                            0.025258       -0.048094  1.000000
# e_grwth(경제성장률)                -0.002774        0.048237 -0.377111
# Seoul_l.rate(지가상승률)           -0.006517       -0.004806 -0.213939
# house_rate(담보대출금리)             0.039514        0.017940  0.149208
# dis_park(국립 공원과의 거리)          -0.072618       -0.105255  0.017893
# dis_highschool(고등학교와의 거리)      0.162671       -0.204004  0.016943
# dis_reconst(재개발 지역과의 거리)       0.214998        0.225095 -0.110684
# dis_univ(대학과의 거리)             -0.702213        0.870612 -0.003616
# dis_hospital(종합 병원과의 거리)      -0.552484        0.167502  0.013588
#
#                            e_grwth(경제성장률)  Seoul_l.rate(지가상승률)  \
# price(가격)                       -0.132575            -0.044081
# con_year(건축년도)                   0.018824             0.003777
# area(면적)                        -0.063985            -0.049426
# floor(층수)                       -0.014200            -0.032827
# Latitude(위도)                    -0.002774            -0.006517
# Longtitude(경도)                   0.048237            -0.004806
# gdp                             -0.377111            -0.213939
# e_grwth(경제성장률)                   1.000000             0.432165
# Seoul_l.rate(지가상승률)              0.432165             1.000000
# house_rate(담보대출금리)              -0.179790            -0.222397
# dis_park(국립 공원과의 거리)            -0.076643            -0.016310
# dis_highschool(고등학교와의 거리)        0.000779             0.012210
# dis_reconst(재개발 지역과의 거리)         0.124114             0.044810
# dis_univ(대학과의 거리)               -0.003406            -0.017573
# dis_hospital(종합 병원과의 거리)        -0.025769             0.035069
#
#                            house_rate(담보대출금리)  ...  dis_hospital(종합 병원과의 거리)  \
# price(가격)                           -0.016064  ...                 -0.027211
# con_year(건축년도)                       0.064364  ...                 -0.567171
# area(면적)                             0.073215  ...                 -0.351692
# floor(층수)                            0.096666  ...                 -0.334654
# Latitude(위도)                         0.039514  ...                 -0.552484
# Longtitude(경도)                       0.017940  ...                  0.167502
# gdp                                  0.149208  ...                  0.013588
# e_grwth(경제성장률)                      -0.179790  ...                 -0.025769
# Seoul_l.rate(지가상승률)                 -0.222397  ...                  0.035069
# house_rate(담보대출금리)                   1.000000  ...                 -0.123207
# dis_park(국립 공원과의 거리)                -0.002624  ...                  0.255695
# dis_highschool(고등학교와의 거리)           -0.010090  ...                  0.070988
# dis_reconst(재개발 지역과의 거리)             0.020718  ...                 -0.220246
# dis_univ(대학과의 거리)                   -0.006254  ...                  0.382893
# dis_hospital(종합 병원과의 거리)            -0.123207  ...                  1.000000
#
#                            dis_museum(국립 박물관과의 거리)  dis_subway(지하철역과의 거리)  \
# price(가격)                                -0.023917               0.032413
# con_year(건축년도)                            0.192700              -0.375835
# area(면적)                                  0.039753              -0.231797
# floor(층수)                                 0.119266              -0.262416
# Latitude(위도)                              0.034464              -0.446530
# Longtitude(경도)                           -0.048959              -0.058008
# gdp                                       0.020654               0.094657
# e_grwth(경제성장률)                            0.008726              -0.069559
# Seoul_l.rate(지가상승률)                       0.037458               0.026834
# house_rate(담보대출금리)                       -0.012885              -0.129616
# dis_park(국립 공원과의 거리)                     -0.093697               0.010135
# dis_highschool(고등학교와의 거리)                 0.028270               0.162948
# dis_reconst(재개발 지역과의 거리)                  0.143299              -0.408034
# dis_univ(대학과의 거리)                        -0.177220               0.215388
# dis_hospital(종합 병원과의 거리)                 -0.135871               0.701023
#
#                            brand_r(유명 아파트 브랜드순)  n_home(세대수)  n_dong(동수)  \
# price(가격)                              0.148241     0.117208    0.077838
# con_year(건축년도)                         0.427227    -0.727402   -0.613206
# area(면적)                               0.146997    -0.350279   -0.382750
# floor(층수)                              0.206511    -0.356595   -0.414505
# Latitude(위도)                           0.129443    -0.429316   -0.454962
# Longtitude(경도)                        -0.271771     0.188727    0.170895
# gdp                                    0.114109     0.060891    0.066403
# e_grwth(경제성장률)                        -0.085838    -0.052561   -0.031194
# Seoul_l.rate(지가상승률)                   -0.018571    -0.002431    0.036049
# house_rate(담보대출금리)                     0.021558    -0.054156   -0.114287
# dis_park(국립 공원과의 거리)                   0.009031     0.319942    0.238979
# dis_highschool(고등학교와의 거리)             -0.002291     0.028045    0.015905
# dis_reconst(재개발 지역과의 거리)               0.048447    -0.383877   -0.348923
# dis_univ(대학과의 거리)                     -0.267132     0.403759    0.396742
# dis_hospital(종합 병원과의 거리)              -0.196103     0.488037    0.592634
#
#                            Yongpae(용적률)  Gunpae(건폐율)  Highest(최고층)  \
# price(가격)                     -0.181609    -0.265625      0.189604
# con_year(건축년도)                 0.513935     0.425801      0.608765
# area(면적)                       0.102846     0.104173      0.346106
# floor(층수)                      0.456448     0.136747      0.621011
# Latitude(위도)                   0.338806     0.406034      0.276134
# Longtitude(경도)                -0.366380    -0.348238     -0.300691
# gdp                           -0.055760    -0.071899      0.026570
# e_grwth(경제성장률)                 0.031346     0.058049     -0.030690
# Seoul_l.rate(지가상승률)           -0.007554     0.016848     -0.045749
# house_rate(담보대출금리)             0.053974    -0.005683      0.123546
# dis_park(국립 공원과의 거리)          -0.072570    -0.078407     -0.073673
# dis_highschool(고등학교와의 거리)      0.015917     0.101806     -0.060888
# dis_reconst(재개발 지역과의 거리)       0.109678     0.138628      0.084104
# dis_univ(대학과의 거리)             -0.453087    -0.448732     -0.386579
# dis_hospital(종합 병원과의 거리)      -0.376078    -0.274252     -0.490496
#
#                            Lowest(최저층)
# price(가격)                     0.099194
# con_year(건축년도)                0.382408
# area(면적)                      0.222335
# floor(층수)                     0.563960
# Latitude(위도)                  0.195107
# Longtitude(경도)               -0.174684
# gdp                          -0.031165
# e_grwth(경제성장률)                0.000478
# Seoul_l.rate(지가상승률)          -0.035941
# house_rate(담보대출금리)            0.120198
# dis_park(국립 공원과의 거리)         -0.019090
# dis_highschool(고등학교와의 거리)    -0.039902
# dis_reconst(재개발 지역과의 거리)      0.092942
# dis_univ(대학과의 거리)            -0.256807
# dis_hospital(종합 병원과의 거리)     -0.396315
#
# [15 rows x 24 columns]

# %% [markdown]
# ## Exercise(5) - Correlations

# %%
# Correlation in 2006Q1

df2006Q1=df[df['yyyyqrt(거래년도 분기별)']=="2006Q1"] # extract data in 2006Q1
df2006Q1_apt=df2006Q1.groupby('aptnm(아파트 이름)').mean() #average price
r = df2006Q1_apt.corr()
r_price = r['price(가격)']

plt.figure(figsize=(20,5))
plt.plot(r_price,'o-')
plt.yticks(fontsize = 20); plt.xticks(rotation=45, fontsize = 15, ha = 'right')
plt.title('2006Q1',fontsize=30); 
plt.grid(True)
plt.show()
# Out:
# findfont: Font family ['Malgun Gothic'] not found. Falling back to DejaVu Sans.
# findfont: Font family ['Malgun Gothic'] not found. Falling back to DejaVu Sans.
# /Users/parkgeonwoo/miniconda3/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 44032 (\N{HANGUL SYLLABLE GA}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/parkgeonwoo/miniconda3/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 44201 (\N{HANGUL SYLLABLE GYEOG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/parkgeonwoo/miniconda3/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 44148 (\N{HANGUL SYLLABLE GEON}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/parkgeonwoo/miniconda3/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 52629 (\N{HANGUL SYLLABLE CUG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/parkgeonwoo/miniconda3/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 45380 (\N{HANGUL SYLLABLE NYEON}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/parkgeonwoo/miniconda3/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 46020 (\N{HANGUL SYLLABLE DO}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/parkgeonwoo/miniconda3/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 47732 (\N{HANGUL SYLLABLE MYEON}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/parkgeonwoo/miniconda3/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 51201 (\N{HANGUL SYLLABLE JEOG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/parkgeonwoo/miniconda3/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 52789 (\N{HANGUL SYLLABLE CEUNG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/parkgeonwoo/miniconda3/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 49688 (\N{HANGUL SYLLABLE SU}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/parkgeonwoo/miniconda3/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 50948 (\N{HANGUL SYLLABLE WI}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/parkgeonwoo/miniconda3/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 44221 (\N{HANGUL SYLLABLE GYEONG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/parkgeonwoo/miniconda3/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 51228 (\N{HANGUL SYLLABLE JE}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/parkgeonwoo/miniconda3/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 49457 (\N{HANGUL SYLLABLE SEONG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/parkgeonwoo/miniconda3/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 51109 (\N{HANGUL SYLLABLE JANG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/parkgeonwoo/miniconda3/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 47456 (\N{HANGUL SYLLABLE RYUL}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/parkgeonwoo/miniconda3/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 51648 (\N{HANGUL SYLLABLE JI}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/parkgeonwoo/miniconda3/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 49345 (\N{HANGUL SYLLABLE SANG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/parkgeonwoo/miniconda3/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 49849 (\N{HANGUL SYLLABLE SEUNG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/parkgeonwoo/miniconda3/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 45812 (\N{HANGUL SYLLABLE DAM}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/parkgeonwoo/miniconda3/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 48372 (\N{HANGUL SYLLABLE BO}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/parkgeonwoo/miniconda3/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 45824 (\N{HANGUL SYLLABLE DAE}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/parkgeonwoo/miniconda3/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 52636 (\N{HANGUL SYLLABLE CUL}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/parkgeonwoo/miniconda3/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 44552 (\N{HANGUL SYLLABLE GEUM}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/parkgeonwoo/miniconda3/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 47532 (\N{HANGUL SYLLABLE RI}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/parkgeonwoo/miniconda3/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 44397 (\N{HANGUL SYLLABLE GUG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/parkgeonwoo/miniconda3/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 47549 (\N{HANGUL SYLLABLE RIB}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/parkgeonwoo/miniconda3/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 44277 (\N{HANGUL SYLLABLE GONG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/parkgeonwoo/miniconda3/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 50896 (\N{HANGUL SYLLABLE WEON}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/parkgeonwoo/miniconda3/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 44284 (\N{HANGUL SYLLABLE GWA}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/parkgeonwoo/miniconda3/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 51032 (\N{HANGUL SYLLABLE YI}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/parkgeonwoo/miniconda3/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 44144 (\N{HANGUL SYLLABLE GEO}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/parkgeonwoo/miniconda3/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 44256 (\N{HANGUL SYLLABLE GO}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/parkgeonwoo/miniconda3/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 46321 (\N{HANGUL SYLLABLE DEUNG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/parkgeonwoo/miniconda3/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 54617 (\N{HANGUL SYLLABLE HAG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/parkgeonwoo/miniconda3/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 44368 (\N{HANGUL SYLLABLE GYO}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/parkgeonwoo/miniconda3/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 50752 (\N{HANGUL SYLLABLE WA}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/parkgeonwoo/miniconda3/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 51116 (\N{HANGUL SYLLABLE JAE}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/parkgeonwoo/miniconda3/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 44060 (\N{HANGUL SYLLABLE GAE}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/parkgeonwoo/miniconda3/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 48156 (\N{HANGUL SYLLABLE BAL}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/parkgeonwoo/miniconda3/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 50669 (\N{HANGUL SYLLABLE YEOG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/parkgeonwoo/miniconda3/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 51333 (\N{HANGUL SYLLABLE JONG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/parkgeonwoo/miniconda3/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 54633 (\N{HANGUL SYLLABLE HAB}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/parkgeonwoo/miniconda3/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 48337 (\N{HANGUL SYLLABLE BYEONG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/parkgeonwoo/miniconda3/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 48149 (\N{HANGUL SYLLABLE BAG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/parkgeonwoo/miniconda3/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 47932 (\N{HANGUL SYLLABLE MUL}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/parkgeonwoo/miniconda3/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 44288 (\N{HANGUL SYLLABLE GWAN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/parkgeonwoo/miniconda3/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 54616 (\N{HANGUL SYLLABLE HA}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/parkgeonwoo/miniconda3/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 52384 (\N{HANGUL SYLLABLE CEOL}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/parkgeonwoo/miniconda3/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 50976 (\N{HANGUL SYLLABLE YU}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/parkgeonwoo/miniconda3/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 47749 (\N{HANGUL SYLLABLE MYEONG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/parkgeonwoo/miniconda3/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 50500 (\N{HANGUL SYLLABLE A}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/parkgeonwoo/miniconda3/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 54028 (\N{HANGUL SYLLABLE PA}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/parkgeonwoo/miniconda3/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 53944 (\N{HANGUL SYLLABLE TEU}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/parkgeonwoo/miniconda3/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 48652 (\N{HANGUL SYLLABLE BEU}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/parkgeonwoo/miniconda3/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 47004 (\N{HANGUL SYLLABLE RAEN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/parkgeonwoo/miniconda3/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 46300 (\N{HANGUL SYLLABLE DEU}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/parkgeonwoo/miniconda3/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 49692 (\N{HANGUL SYLLABLE SUN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/parkgeonwoo/miniconda3/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 49464 (\N{HANGUL SYLLABLE SE}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/parkgeonwoo/miniconda3/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 46041 (\N{HANGUL SYLLABLE DONG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/parkgeonwoo/miniconda3/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 50857 (\N{HANGUL SYLLABLE YONG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/parkgeonwoo/miniconda3/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 54224 (\N{HANGUL SYLLABLE PYE}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/parkgeonwoo/miniconda3/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 50984 (\N{HANGUL SYLLABLE YUL}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/parkgeonwoo/miniconda3/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 52572 (\N{HANGUL SYLLABLE COE}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/parkgeonwoo/miniconda3/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 51200 (\N{HANGUL SYLLABLE JEO}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# findfont: Font family ['Malgun Gothic'] not found. Falling back to DejaVu Sans.

# %%
# Correlations in other years.

years = ['2006Q1', '2016Q1', '2017Q1', '2017Q2']

for y in years:
    df_y=df[df['yyyyqrt(거래년도 분기별)']==y] # extract data in 2006Q1
    df_y_apt=df_y.groupby('aptnm(아파트 이름)').mean() #average price
    df_r = df_y_apt.corr()
    df_r_price = df_r['price(가격)']
    if y==years[0]:
        df_r_price_all = df_r_price
    else:
        df_r_price_all = pd.concat([df_r_price_all,df_r_price],axis=1)
df_r_price_all.columns = years


plt.figure(figsize=(20,10))
plt.plot(df_r_price_all,'o-')
plt.yticks(fontsize =20);plt.xticks(rotation=45,fontsize=15,ha='right')
plt.grid(True)
plt.legend(years,fontsize=20)
plt.show()
# Out:
# /Users/parkgeonwoo/miniconda3/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 44032 (\N{HANGUL SYLLABLE GA}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/parkgeonwoo/miniconda3/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 44201 (\N{HANGUL SYLLABLE GYEOG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/parkgeonwoo/miniconda3/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 44148 (\N{HANGUL SYLLABLE GEON}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/parkgeonwoo/miniconda3/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 52629 (\N{HANGUL SYLLABLE CUG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/parkgeonwoo/miniconda3/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 45380 (\N{HANGUL SYLLABLE NYEON}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/parkgeonwoo/miniconda3/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 46020 (\N{HANGUL SYLLABLE DO}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/parkgeonwoo/miniconda3/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 47732 (\N{HANGUL SYLLABLE MYEON}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/parkgeonwoo/miniconda3/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 51201 (\N{HANGUL SYLLABLE JEOG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/parkgeonwoo/miniconda3/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 52789 (\N{HANGUL SYLLABLE CEUNG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/parkgeonwoo/miniconda3/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 49688 (\N{HANGUL SYLLABLE SU}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/parkgeonwoo/miniconda3/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 50948 (\N{HANGUL SYLLABLE WI}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/parkgeonwoo/miniconda3/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 44221 (\N{HANGUL SYLLABLE GYEONG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/parkgeonwoo/miniconda3/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 51228 (\N{HANGUL SYLLABLE JE}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/parkgeonwoo/miniconda3/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 49457 (\N{HANGUL SYLLABLE SEONG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/parkgeonwoo/miniconda3/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 51109 (\N{HANGUL SYLLABLE JANG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/parkgeonwoo/miniconda3/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 47456 (\N{HANGUL SYLLABLE RYUL}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/parkgeonwoo/miniconda3/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 51648 (\N{HANGUL SYLLABLE JI}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/parkgeonwoo/miniconda3/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 49345 (\N{HANGUL SYLLABLE SANG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/parkgeonwoo/miniconda3/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 49849 (\N{HANGUL SYLLABLE SEUNG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/parkgeonwoo/miniconda3/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 45812 (\N{HANGUL SYLLABLE DAM}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/parkgeonwoo/miniconda3/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 48372 (\N{HANGUL SYLLABLE BO}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/parkgeonwoo/miniconda3/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 45824 (\N{HANGUL SYLLABLE DAE}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/parkgeonwoo/miniconda3/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 52636 (\N{HANGUL SYLLABLE CUL}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/parkgeonwoo/miniconda3/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 44552 (\N{HANGUL SYLLABLE GEUM}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/parkgeonwoo/miniconda3/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 47532 (\N{HANGUL SYLLABLE RI}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/parkgeonwoo/miniconda3/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 44397 (\N{HANGUL SYLLABLE GUG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/parkgeonwoo/miniconda3/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 47549 (\N{HANGUL SYLLABLE RIB}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/parkgeonwoo/miniconda3/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 44277 (\N{HANGUL SYLLABLE GONG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/parkgeonwoo/miniconda3/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 50896 (\N{HANGUL SYLLABLE WEON}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/parkgeonwoo/miniconda3/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 44284 (\N{HANGUL SYLLABLE GWA}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/parkgeonwoo/miniconda3/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 51032 (\N{HANGUL SYLLABLE YI}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/parkgeonwoo/miniconda3/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 44144 (\N{HANGUL SYLLABLE GEO}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/parkgeonwoo/miniconda3/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 44256 (\N{HANGUL SYLLABLE GO}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/parkgeonwoo/miniconda3/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 46321 (\N{HANGUL SYLLABLE DEUNG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/parkgeonwoo/miniconda3/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 54617 (\N{HANGUL SYLLABLE HAG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/parkgeonwoo/miniconda3/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 44368 (\N{HANGUL SYLLABLE GYO}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/parkgeonwoo/miniconda3/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 50752 (\N{HANGUL SYLLABLE WA}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/parkgeonwoo/miniconda3/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 51116 (\N{HANGUL SYLLABLE JAE}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/parkgeonwoo/miniconda3/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 44060 (\N{HANGUL SYLLABLE GAE}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/parkgeonwoo/miniconda3/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 48156 (\N{HANGUL SYLLABLE BAL}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/parkgeonwoo/miniconda3/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 50669 (\N{HANGUL SYLLABLE YEOG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/parkgeonwoo/miniconda3/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 51333 (\N{HANGUL SYLLABLE JONG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/parkgeonwoo/miniconda3/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 54633 (\N{HANGUL SYLLABLE HAB}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/parkgeonwoo/miniconda3/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 48337 (\N{HANGUL SYLLABLE BYEONG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/parkgeonwoo/miniconda3/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 48149 (\N{HANGUL SYLLABLE BAG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/parkgeonwoo/miniconda3/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 47932 (\N{HANGUL SYLLABLE MUL}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/parkgeonwoo/miniconda3/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 44288 (\N{HANGUL SYLLABLE GWAN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/parkgeonwoo/miniconda3/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 54616 (\N{HANGUL SYLLABLE HA}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/parkgeonwoo/miniconda3/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 52384 (\N{HANGUL SYLLABLE CEOL}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/parkgeonwoo/miniconda3/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 50976 (\N{HANGUL SYLLABLE YU}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/parkgeonwoo/miniconda3/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 47749 (\N{HANGUL SYLLABLE MYEONG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/parkgeonwoo/miniconda3/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 50500 (\N{HANGUL SYLLABLE A}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/parkgeonwoo/miniconda3/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 54028 (\N{HANGUL SYLLABLE PA}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/parkgeonwoo/miniconda3/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 53944 (\N{HANGUL SYLLABLE TEU}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/parkgeonwoo/miniconda3/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 48652 (\N{HANGUL SYLLABLE BEU}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/parkgeonwoo/miniconda3/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 47004 (\N{HANGUL SYLLABLE RAEN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/parkgeonwoo/miniconda3/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 46300 (\N{HANGUL SYLLABLE DEU}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/parkgeonwoo/miniconda3/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 49692 (\N{HANGUL SYLLABLE SUN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/parkgeonwoo/miniconda3/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 49464 (\N{HANGUL SYLLABLE SE}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/parkgeonwoo/miniconda3/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 46041 (\N{HANGUL SYLLABLE DONG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/parkgeonwoo/miniconda3/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 50857 (\N{HANGUL SYLLABLE YONG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/parkgeonwoo/miniconda3/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 54224 (\N{HANGUL SYLLABLE PYE}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/parkgeonwoo/miniconda3/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 50984 (\N{HANGUL SYLLABLE YUL}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/parkgeonwoo/miniconda3/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 52572 (\N{HANGUL SYLLABLE COE}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/parkgeonwoo/miniconda3/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 51200 (\N{HANGUL SYLLABLE JEO}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %% [markdown]
# ## Exercise(6) - AR(1)

# %%
nMA = 2 # number of Pre(or post) samples to average

plt.figure(figsize=(50,15))
mask=df[df['dong(동)']=="역삼동"]
m=mask.groupby('yyyyqrt(거래년도 분기별)').mean().copy()
ls=[]
for j in range(nMA,len(m)-nMA):
    ls.append(m['price(가격)'].iloc[j-nMA:j+nMA].mean())
df_mean5=pd.DataFrame({"Time" : m.index.values[nMA:len(m)-nMA], "Mean_Price" : ls })
plt.plot(df_mean5["Time"],df_mean5["Mean_Price"],linewidth=3.0)
plt.yticks(fontsize = 50); plt.xticks(fontsize = 30, rotation = 45, ha = 'right')
plt.grid(True)

# %%
plot_acf(df_mean5['Mean_Price'])
plt.show()
# Out:
# findfont: Font family ['Malgun Gothic'] not found. Falling back to DejaVu Sans.

# %%
# Difference
plt.figure(figsize=(50,15))
diff_1=df_mean5.diff(periods=1).iloc[1:]
plot_pacf(df_mean5['Mean_Price'])
plt.show()

plt.yticks(fontsize = 50); plt.xticks(fontsize = 30, rotation = 45, ha = 'right')
plt.plot(diff_1,  linewidth=3.0)
plt.axhline(y=0, color='r', linewidth=3.0)
plt.grid(True)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /var/folders/23/f42cny6d2td3m03jprj58vt40000gn/T/ipykernel_30194/1570854077.py in <module>
#       1 # Difference
#       2 plt.figure(figsize=(50,15))
# ----> 3 diff_1=df_mean5.diff(periods=1).iloc[1:]
#       4 plot_pacf(df_mean5['Mean_Price'])
#       5 plt.show()
#
# ~/miniconda3/lib/python3.9/site-packages/pandas/core/frame.py in diff(self, periods, axis)
#    8526             return self - self.shift(periods, axis=axis)
#    8527
# -> 8528         new_data = self._mgr.diff(n=periods, axis=axis)
#    8529         return self._constructor(new_data).__finalize__(self, "diff")
#    8530
#
# ~/miniconda3/lib/python3.9/site-packages/pandas/core/internals/managers.py in diff(self, n, axis)
#     354     def diff(self: T, n: int, axis: int) -> T:
#     355         axis = self._normalize_axis(axis)
# --> 356         return self.apply("diff", n=n, axis=axis)
#     357
#     358     def interpolate(self: T, **kwargs) -> T:
#
# ~/miniconda3/lib/python3.9/site-packages/pandas/core/internals/managers.py in apply(self, f, align_keys, ignore_failures, **kwargs)
#     302                     applied = b.apply(f, **kwargs)
#     303                 else:
# --> 304                     applied = getattr(b, f)(**kwargs)
#     305             except (TypeError, NotImplementedError):
#     306                 if not ignore_failures:
#
# ~/miniconda3/lib/python3.9/site-packages/pandas/core/internals/blocks.py in diff(self, n, axis)
#    1136     def diff(self, n: int, axis: int = 1) -> list[Block]:
#    1137         """return block for the diff of the values"""
# -> 1138         new_values = algos.diff(self.values, n, axis=axis)
#    1139         return [self.make_block(values=new_values)]
#    1140
#
# ~/miniconda3/lib/python3.9/site-packages/pandas/core/algorithms.py in diff(arr, n, axis)
#    1645         lag_indexer = tuple(_lag_indexer)
#    1646
# -> 1647         out_arr[res_indexer] = op(arr[res_indexer], arr[lag_indexer])
#    1648
#    1649     if is_timedelta:
#
# TypeError: unsupported operand type(s) for -: 'str' and 'str'

# %%
plot_acf(diff_1)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/23/f42cny6d2td3m03jprj58vt40000gn/T/ipykernel_30194/1407515968.py in <module>
# ----> 1 plot_acf(diff_1)
#       2 plt.show()
#
# NameError: name 'diff_1' is not defined

# %%
from statsmodels.tsa.arima_model import ARIMA
train = diff_1.iloc[:38] # 38 out of 42 samples
test = diff_1.iloc[38:] # 4 out of 42 samples
model = ARIMA(train, order=(1,0,0)) # order=(p,d,q), here we only use  p = 1

# Nc: No constant used / convergence information is not printed
model_fit = model.fit(trend='Nc',disp=0);
print(model_fit.summary())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/23/f42cny6d2td3m03jprj58vt40000gn/T/ipykernel_30194/367012814.py in <module>
#       1 from statsmodels.tsa.arima_model import ARIMA
# ----> 2 train = diff_1.iloc[:38] # 38 out of 42 samples
#       3 test = diff_1.iloc[38:] # 4 out of 42 samples
#       4 model = ARIMA(train, order=(1,0,0)) # order=(p,d,q), here we only use  p = 1
#       5
#
# NameError: name 'diff_1' is not defined

# %%
# plot the result (predicted value and true value) for traing samples
predict = model_fit.plot_predict()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/23/f42cny6d2td3m03jprj58vt40000gn/T/ipykernel_30194/1326993653.py in <module>
#       1 # plot the result (predicted value and true value) for traing samples
# ----> 2 predict = model_fit.plot_predict()
#
# NameError: name 'model_fit' is not defined

# %%
fc, se, conf = model_fit.forecast(steps=4, alpha=0.05)  # 95% conf
fc_series = pd.Series(fc, index=test.index)
plt.figure(figsize=(40,10), dpi=100)
plt.plot(diff_1, linewidth = 3.0, label='training')
plt.plot(test,  linewidth = 3.0, label='actual')
plt.plot(fc_series, linewidth = 3.0, label='forecast')
plt.legend(fontsize=50)
plt.yticks(fontsize = 50); plt.xticks(fontsize = 30, rotation = 45, ha = 'right')
plt.grid(True)

#**** code for highlight the target area ***
#lower_series = pd.Series(conf[:, 0], index=test.index)
#upper_series = pd.Series(conf[:, 1], index=test.index)
#plt.fill_between(lower_series.index, lower_series, upper_series, color='k', alpha=.15)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/23/f42cny6d2td3m03jprj58vt40000gn/T/ipykernel_30194/1900037246.py in <module>
# ----> 1 fc, se, conf = model_fit.forecast(steps=4, alpha=0.05)  # 95% conf
#       2 fc_series = pd.Series(fc, index=test.index)
#       3 plt.figure(figsize=(40,10), dpi=100)
#       4 plt.plot(diff_1, linewidth = 3.0, label='training')
#       5 plt.plot(test,  linewidth = 3.0, label='actual')
#
# NameError: name 'model_fit' is not defined
